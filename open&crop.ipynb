# %%
import cv2
img = cv2.imread("./images/person.jpg")

# %%
import matplotlib.pyplot as plt
plt.imshow(img[:, :, ::-1])

# %%
cropped = img[10:140, 210:340, ::-1]
plt.imshow(cropped)

# %%
cv2.imwrite("Images/output.jpg", cropped)
# Out:
# True
