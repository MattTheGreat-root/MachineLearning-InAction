# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_id = "gpt2"

gpt2_tokenizer = AutoTokenizer.from_pretrained(model_id)
gpt2 = AutoModelForCausalLM.from_pretrained(model_id, device_map = "auto", dtype = "auto")
# Out:
# '[Errno 54] Connection reset by peer' thrown while requesting HEAD https://huggingface.co/gpt2/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 model_id = "gpt2"
#       2
# ----> 3 gpt2_tokenizer = AutoTokenizer.from_pretrained(model_id)
#       4 gpt2 = AutoModelForCausalLM.from_pretrained(model_id, device_map = "auto", dtype = "auto")
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/transformers/models/auto/tokenization_auto.py:696, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     692         config = AutoConfig.from_pretrained(
#     693             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     694         )
#     695     except (ValueError, OSError):
# --> 696         config = PreTrainedConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     698 config_model_type = config.model_type
#     700 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/transformers/configuration_utils.py:641, in PreTrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     638 kwargs["local_files_only"] = local_files_only
#     639 kwargs["revision"] = revision
# --> 641 config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     642 if cls.base_config_key and cls.base_config_key in config_dict:
#     643     config_dict = config_dict[cls.base_config_key]
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/transformers/configuration_utils.py:682, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     680 original_kwargs = copy.deepcopy(kwargs)
#     681 # Get config dict associated with the base config file
# --> 682 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     683 if config_dict is None:
#     684     return {}, kwargs
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/transformers/configuration_utils.py:737, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     733 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     735 try:
#     736     # Load from local folder or from cache or download from model Hub and cache
# --> 737     resolved_config_file = cached_file(
#     738         pretrained_model_name_or_path,
#     739         configuration_file,
#     740         cache_dir=cache_dir,
#     741         force_download=force_download,
#     742         proxies=proxies,
#     743         local_files_only=local_files_only,
#     744         token=token,
#     745         user_agent=user_agent,
#     746         revision=revision,
#     747         subfolder=subfolder,
#     748         _commit_hash=commit_hash,
#     749     )
#     750     if resolved_config_file is None:
#     751         return None, kwargs
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/transformers/utils/hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)    276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/transformers/utils/hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     419 try:
#     420     if len(full_filenames) == 1:
#     421         # This is slightly better for only 1 file
# --> 422         hf_hub_download(
#     423             path_or_repo_id,
#     424             filenames[0],
#     425             subfolder=None if len(subfolder) == 0 else subfolder,
#     426             repo_type=repo_type,
#     427             revision=revision,
#     428             cache_dir=cache_dir,
#     429             user_agent=user_agent,
#     430             force_download=force_download,
#     431             proxies=proxies,
#     432             token=token,
#     433             local_files_only=local_files_only,
#     434             tqdm_class=tqdm_class,
#     435         )
#     436     else:
#     437         snapshot_download(
#     438             path_or_repo_id,
#     439             allow_patterns=full_filenames,
#    (...)    448             tqdm_class=tqdm_class,
#     449         )
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:997, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     976     return _hf_hub_download_to_local_dir(
#     977         # Destination
#     978         local_dir=local_dir,
#    (...)    994         dry_run=dry_run,
#     995     )
#     996 else:
# --> 997     return _hf_hub_download_to_cache_dir(
#     998         # Destination
#     999         cache_dir=cache_dir,
#    1000         # File info
#    1001         repo_id=repo_id,
#    1002         filename=filename,
#    1003         repo_type=repo_type,
#    1004         revision=revision,
#    1005         # HTTP info
#    1006         endpoint=endpoint,
#    1007         etag_timeout=etag_timeout,
#    1008         headers=hf_headers,
#    1009         token=token,
#    1010         # Additional options
#    1011         local_files_only=local_files_only,
#    1012         force_download=force_download,
#    1013         tqdm_class=tqdm_class,
#    1014         dry_run=dry_run,
#    1015     )
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:1130, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1124     if isinstance(head_call_error, _DEFAULT_RETRY_ON_EXCEPTIONS) or (
#    1125         isinstance(head_call_error, HfHubHTTPError)
#    1126         and head_call_error.response.status_code in _DEFAULT_RETRY_ON_STATUS_CODES
#    1127     ):
#    1128         logger.info("No local file found. Retrying..")
#    1129         (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = (
# -> 1130             _get_metadata_or_catch_error(
#    1131                 repo_id=repo_id,
#    1132                 filename=filename,
#    1133                 repo_type=repo_type,
#    1134                 revision=revision,
#    1135                 endpoint=endpoint,
#    1136                 etag_timeout=_ETAG_RETRY_TIMEOUT,
#    1137                 headers=headers,
#    1138                 token=token,
#    1139                 local_files_only=local_files_only,
#    1140                 storage_folder=storage_folder,
#    1141                 relative_filename=relative_filename,
#    1142                 retry_on_errors=True,
#    1143             )
#    1144         )
#    1146 # If still error, raise
#    1147 if head_call_error is not None:
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:1669, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1667 try:
#    1668     try:
# -> 1669         metadata = get_hf_file_metadata(
#    1670             url=url,
#    1671             timeout=etag_timeout,
#    1672             headers=headers,
#    1673             token=token,
#    1674             endpoint=endpoint,
#    1675             retry_on_errors=retry_on_errors,
#    1676         )
#    1677     except RemoteEntryNotFoundError as http_error:
#    1678         if storage_folder is not None and relative_filename is not None:
#    1679             # Cache the non-existence of the file
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:1591, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1588 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1590 # Retrieve metadata
# -> 1591 response = _httpx_follow_relative_redirects_with_backoff(
#    1592     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1593 )
#    1594 hf_raise_for_status(response)
#    1596 # Return
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_http.py:685, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     680 no_retry_kwargs: dict[str, Any] = (
#     681     {} if retry_on_errors else {"retry_on_exceptions": (), "retry_on_status_codes": ()}
#     682 )
#     684 while True:
# --> 685     response = http_backoff(
#     686         method=method,
#     687         url=url,
#     688         **httpx_kwargs,
#     689         follow_redirects=False,
#     690         **no_retry_kwargs,
#     691     )
#     692     hf_raise_for_status(response)
#     694     # Check if response is a relative redirect
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_http.py:559, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     494 def http_backoff(
#     495     method: HTTP_METHOD_T,
#     496     url: str,
#    (...)    503     **kwargs,
#     504 ) -> httpx.Response:
#     505     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     506
#     507     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)    557     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     558     """
# --> 559     return next(
#     560         _http_backoff_base(
#     561             method=method,
#     562             url=url,
#     563             max_retries=max_retries,
#     564             base_wait_time=base_wait_time,
#     565             max_wait_time=max_wait_time,
#     566             retry_on_exceptions=retry_on_exceptions,
#     567             retry_on_status_codes=retry_on_status_codes,
#     568             stream=False,
#     569             **kwargs,
#     570         )
#     571     )
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_http.py:467, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     465             return
#     466 else:
# --> 467     response = client.request(method=method, url=url, **kwargs)
#     468     if not _should_retry(response):
#     469         yield response
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99 except BaseException as exc:
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      76 with self._request_lock:
#      77     if self._connection is None:
# ---> 78         stream = self._connect(request)
#      80         ssl_object = stream.get_extra_info("ssl_object")
#      81         http2_negotiated = (
#      82             ssl_object is not None
#      83             and ssl_object.selected_alpn_protocol() == "h2"
#      84         )
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     116     kwargs = {
#     117         "host": self._origin.host.decode("ascii"),
#     118         "port": self._origin.port,
#    (...)    121         "socket_options": self._socket_options,
#     122     }
#     123     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124         stream = self._network_backend.connect_tcp(**kwargs)
#     125         trace.return_value = stream
#     126 else:
#
# File ~/Desktop/Codes/Projects/MachineLearning-InAction/.venv/lib/python3.14/site-packages/httpcore/_backends/sync.py:208, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
#     207 with map_exceptions(exc_map):
# --> 208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#     213     for option in socket_options:
#     214         sock.setsockopt(*option)  # pragma: no cover
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:855, in create_connection(address, timeout, source_address, all_errors)
#     853 if source_address:
#     854     sock.bind(source_address)
# --> 855 sock.connect(sa)
#     856 # Break explicitly a reference cycle
#     857 exceptions.clear()
#
# KeyboardInterrupt:

# %%
def generate(model, tokenizer, prompt, max_new_tokens=50, **generate_kwargs):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(**inputs, max_new_tokens=max_new_tokens, pad_token_id=tokenizer.eos_token_id, **generate_kwargs)
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
torch.manual_seed(42)

prompt = "Scientists found a talking unicorn today. Here's the full story:"
generate(gpt2, gpt2_tokenizer, prompt, do_sample=True, top_p=0.6)
