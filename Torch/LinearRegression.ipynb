# %%
import sys
print(sys.executable)
# Out:
# /Users/matin/Desktop/Codes/Projects/Learn CV/.venv/bin/python

# %%
import torch.nn as nn

# %%
import torch

# %%
from sklearn.datasets import fetch_california_housing

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# I will
# assume you have already downloaded it using
# sklearn.datasets.fetch_california_housing(), and you have split it
# into a training set (X_train and y_train), a validation set (X_valid and y_valid), and a test set (X_test and y_test), using sklearn.model_selection.train_test_split().

# %%
data = fetch_california_housing()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/homebrew/Cellar/python@3.14/3.14.2_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/urllib/request.py:1321, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1320 try:
# -> 1321     h.request(req.get_method(), req.selector, req.data, headers,
#    1322               encode_chunked=req.has_header('Transfer-encoding'))
#    1323 except OSError as err: # timeout error
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:1358, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1357 """Send a complete request to the server."""
# -> 1358 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
X_train = torch.FloatTensor(X_train)
X_valid = torch.FloatTensor(X_valid)
X_test = torch.FloatTensor(X_test)
means = X_train.mean(dim=0, keepdims=True)
stds = X_train.std(dim=0, keepdims=True)
X_train = (X_train - means) / stds
X_valid = (X_valid - means) / stds
X_test = (X_test - means) / stds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X_train = torch.FloatTensor(X_train)
#       2 X_valid = torch.FloatTensor(X_valid)
#       3 X_test = torch.FloatTensor(X_test)
#
# NameError: name 'X_train' is not defined

# %%
y_train = torch.FloatTensor(y_train).reshape(-1, 1)
y_valid = torch.FloatTensor(y_valid).reshape(-1, 1)
y_test = torch.FloatTensor(y_test).reshape(-1, 1)

# %%
torch.manual_seed(42)
n_features = X_train.shape[1] 
model = nn.Linear(in_features = n_features, out_features = 1)

# %%
learning_rate = 0.4
n_epochs = 20
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
mse = nn.MSELoss()

# %%
def train_bgd(model, optimizer, criterion, X_train, y_train, n_epochs):
    for epoch in range(n_epochs):
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        print(f"Epoch {epoch + 1}/{n_epochs}, Loss: {loss.item()}")

# %%
train_bgd(model, optimizer, mse ,X_train, y_train, n_epochs)
